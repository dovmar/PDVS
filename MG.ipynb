# %%
import pandas as pd
pd.set_option('display.float_format', lambda x: '%.3f' % x)
import numpy as np
from scipy import stats
import seaborn as sns
sns.set(rc = {'figure.figsize':(17,7)})
import matplotlib.pyplot as plt

# %% [markdown]
# ### 1

# %%
d = pd.read_csv("Future-500-4.csv")
d
# Out:
#                  Name      Industry Inception  Employees State  \
# 0            Over-Hex      Software    2006.0     25.000    TN
# 1           Unimattax   IT Services    2009.0     36.000    PA
# 2            Greenfax        Retail    2012.0     28.000    SC
# 3           Blacklane   IT Services    2011.0     66.000    CA
# 4            Yearflex      Software    2013.0     45.000    WI
# ..                ...           ...       ...        ...   ...
# 487  Buretteadmirable   IT Services    2009.0     93.000    ME
# 488  Inventtremendous  Construction    2009.0     24.000    MN
# 489    Overviewparrot        Retail    2011.0   7125.000    TX
# 490        Belaguerra   IT Services    2010.0    140.000    MI
# 491       Allpossible   IT Services    2011.0     24.000    CA
#
#                City      Revenue    Expenses       Profit  Growth
# 0          Franklin  9684527.000 1130700.000  8553827.000  19.000
# 1    Newtown Square 14016543.000  804035.000 13212508.000  20.000
# 2        Greenville  9746272.000 1044375.000  8701897.000  16.000
# 3            Orange 15359369.000 4631808.000 10727561.000  19.000
# 4           Madison  8567910.000 4374841.000  4193069.000  19.000
# ..              ...          ...         ...          ...     ...
# 487        Portland 15407450.000 2833136.000 12574314.000  25.000
# 488        Woodbury  9144857.000 4755995.000  4388862.000  11.000
# 489      Fort Worth 11134728.000 5152110.000  5982618.000  12.000
# 490            Troy 17387130.000 1387784.000 15999346.000  23.000
# 491     Los Angeles 11949706.000  689161.000 11260545.000  24.000
#
# [492 rows x 10 columns]

# %% [markdown]
# ### 2

# %%
d = d.drop(["ID"], axis = 1)
d.Revenue = d.Revenue.str.replace(r'\D+', '', regex = True)
d.Expenses = d.Expenses.str.replace(r'\D+', '', regex = True)
d.Growth = d.Growth.str.replace(r'\D+', '', regex = True)
d = d.astype({'Inception':'string',
              'Employees':'float',
              'Revenue':'float',
              'Expenses':'float',
              'Profit':'float',
              'Growth':'float',
              'Name':'string',
              'Industry':'string',
              'State':'string',
              'City':'string',})

# %%
d.head()
# Out:
#         Name     Industry Inception  Employees State            City  \
# 0   Over-Hex     Software    2006.0     25.000    TN        Franklin
# 1  Unimattax  IT Services    2009.0     36.000    PA  Newtown Square
# 2   Greenfax       Retail    2012.0        NaN    SC      Greenville
# 3  Blacklane  IT Services    2011.0     66.000    CA          Orange
# 4   Yearflex     Software    2013.0     45.000    WI         Madison
#
#        Revenue    Expenses       Profit  Growth
# 0  9684527.000 1130700.000  8553827.000  19.000
# 1 14016543.000  804035.000 13212508.000  20.000
# 2  9746272.000 1044375.000  8701897.000  16.000
# 3 15359369.000 4631808.000 10727561.000  19.000
# 4  8567910.000 4374841.000  4193069.000  19.000

# %%
d.describe()
# Out:
#        Employees      Revenue    Expenses       Profit  Growth
# count    496.000      496.000     495.000      498.000 498.000
# mean     149.085 10847567.242 4315806.725  6539474.014  14.392
# std      398.084  3191399.824 2115947.993  3869933.654   6.857
# min        1.000  1614585.000   71219.000    12434.000   0.000
# 25%       27.750  8696767.250 2765292.000  3272073.750   8.000
# 50%       57.000 10647231.000 4365512.000  6513366.000  15.000
# 75%      126.000 13101110.000 5833973.000  9303950.750  20.000
# max     7125.000 21810051.000 9860686.000 19624534.000  30.000

# %%
industries = ['Health','Financial Services','Construction','Software','IT Services','Government Services','Retail']
emp = []
rev = []
exp = []
profit = []
growth = []
for ind in industries:
    des = d[d.Industry == ind].describe().values
    emp.append([i[0] for i in des])
    rev.append([i[1] for i in des])
    exp.append([i[2] for i in des])
    profit.append([i[3] for i in des])
    growth.append([i[4] for i in des])

# %%
emp = np.array(emp).reshape((8, 7))
rev = np.array(rev).reshape((8, 7))
exp = np.array(exp).reshape((8, 7))
profit = np.array(profit).reshape((8, 7))
growth = np.array(growth).reshape((8, 7))

# %%
columns = industries
indexes = ['count', 'mean', 'std', 'min', '25%', '50%', '75%', 'max']

# %%
pd.DataFrame(data = emp, columns = columns, index = indexes).plot(figsize  = (15, 5), title = "Employees", linewidth = 2.5)
# Out:
# <AxesSubplot:title={'center':'Employees'}>

# %%
pd.DataFrame(data = rev, columns = columns, index = indexes).plot(figsize  = (15, 5), title = "Revenue", linewidth = 2.5)
# Out:
# <AxesSubplot:title={'center':'Revenue'}>

# %%
pd.DataFrame(data = exp, columns = columns, index = indexes).plot(figsize  = (15, 5), title = "Expenses", linewidth = 2.5)
# Out:
# <AxesSubplot:title={'center':'Expenses'}>

# %%
pd.DataFrame(data = profit, columns = columns, index = indexes).plot(figsize  = (15, 5), title = "Profit", linewidth = 2.5)
# Out:
# <AxesSubplot:title={'center':'Profit'}>

# %%
pd.DataFrame(data = growth, columns = columns, index = indexes).plot(figsize  = (15, 5), title = "Growth", linewidth = 2.5)
# Out:
# <AxesSubplot:title={'center':'Growth'}>

# %% [markdown]
# ### 3

# %%
d.isna().sum()
# Out:
# Name         0
# Industry     2
# Inception    1
# Employees    4
# State        6
# City         0
# Revenue      4
# Expenses     5
# Profit       2
# Growth       2
# dtype: int64

# %% [markdown]
# Industrijos ir sukūrimo metų neįmanoma užpildyti, tad pašalinsiu

# %%
d = d.drop(index = d[(d.Industry.isnull()) | (d.Inception.isnull())].index, axis = 1)
d = d.reset_index(drop = True)

# %% [markdown]
# #### Employees

# %%
inter_ind_empl_dict = dict(d.groupby(['Industry'])['Employees'].median())
inter_ind_empl_dict
# Out:
# {'Construction': 38.0,
#  'Financial Services': 80.0,
#  'Government Services': 99.0,
#  'Health': 85.0,
#  'IT Services': 52.0,
#  'Retail': 28.0,
#  'Software': 62.0}

# %%
emp_nans = d[d.Employees.isnull()]
d.iloc[emp_nans.index, 3] = [inter_ind_empl_dict[i] for i in emp_nans.Industry]
print("Employees turi tiek NA:", d.isna().sum().Employees)
# Out:
# Employees turi tiek NA: 0

# %% [markdown]
# #### State

# %%
temp = d[d.State.isnull()]

NYindex = temp[temp.City == "New York"].index
d.iloc[NYindex, 4] = "NY"

NBindex = temp[temp.City == "Newport Beach"].index
d.iloc[NBindex, 4] = "CA"

ALindex = temp[temp.City == "Alpharetta"].index
d.iloc[ALindex, 4] = "GA"

SFindex = temp[temp.City == "San Francisco"].index
d.iloc[SFindex, 4] = "CA"

print("State turi tiek NA:", d.isna().sum().State)
# Out:
# State turi tiek NA: 0

# %% [markdown]
# #### Revenue, Expenses, Profit

# %%
d = d.drop(index = d[(d.Revenue.isnull()) & (d.Expenses.isnull())].index, axis = 1)
d = d.reset_index(drop = True)
d = d.drop(index = d[d.Growth.isnull()].index, axis = 1)
d = d.reset_index(drop = True)

# %%
revnan = d[d.Revenue.isnull()] 
revnan.Revenue = d.Expenses + d.Profit 
d.iloc[revnan.index, :] = revnan 

expnan = d[d.Expenses.isnull()] 
expnan.Expenses = d.Revenue - d.Profit 
d.iloc[expnan.index, :] = expnan

print("Revenue turi tiek NA:", d.isna().sum().Revenue)
print("Expenses turi tiek NA:", d.isna().sum().Expenses)
print("Profit turi tiek NA:", d.isna().sum().Profit)
# Out:
# Revenue turi tiek NA: 0
# Expenses turi tiek NA: 0
# Profit turi tiek NA: 0
# C:\Users\dovyd\anaconda3\lib\site-packages\pandas\core\generic.py:5516: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %% [markdown]
# #### Nebėra praleistų reikšmių

# %%
d.isna().sum()
# Out:
# Name         0
# Industry     0
# Inception    0
# Employees    0
# State        0
# City         0
# Revenue      0
# Expenses     0
# Profit       0
# Growth       0
# dtype: int64

# %% [markdown]
# ### 4

# %%
dropped = 0
for col in d.columns[-4:]:
    indextodrop = d[(np.abs(stats.zscore(d[col])) >= 3)].index
    d = d = d.drop(index = indextodrop, axis = 1)
    d = d.reset_index(drop = True)
    
    dropped += len(indextodrop)

print("Pašalinta išskirčių:", dropped)
# Out:
# Pašalinta išskirčių: 2

# %% [markdown]
# ### 5

# %%
def norm_minmax(col):
    mini = np.nanmin(col)
    maxi = np.nanmax(col)
    return (col - mini) / ( maxi - mini)

# %%
normd = d.copy()

colstonorm = ["Employees", "Revenue", "Expenses", "Profit", "Growth"]
for col in colstonorm:
    normd[col] = norm_minmax(normd[col])

# %%
normd
# Out:
#                  Name      Industry Inception  Employees State  \
# 0            Over-Hex      Software    2006.0      0.003    TN
# 1           Unimattax   IT Services    2009.0      0.005    PA
# 2            Greenfax        Retail    2012.0      0.004    SC
# 3           Blacklane   IT Services    2011.0      0.009    CA
# 4            Yearflex      Software    2013.0      0.006    WI
# ..                ...           ...       ...        ...   ...
# 487  Buretteadmirable   IT Services    2009.0      0.013    ME
# 488  Inventtremendous  Construction    2009.0      0.003    MN
# 489    Overviewparrot        Retail    2011.0      1.000    TX
# 490        Belaguerra   IT Services    2010.0      0.020    MI
# 491       Allpossible   IT Services    2011.0      0.003    CA
#
#                City  Revenue  Expenses  Profit  Growth
# 0          Franklin    0.476     0.108   0.534   0.633
# 1    Newtown Square    0.731     0.075   0.826   0.667
# 2        Greenville    0.480     0.099   0.544   0.533
# 3            Orange    0.811     0.466   0.670   0.633
# 4           Madison    0.410     0.440   0.262   0.633
# ..              ...      ...       ...     ...     ...
# 487        Portland    0.814     0.282   0.786   0.833
# 488        Woodbury    0.444     0.479   0.274   0.367
# 489      Fort Worth    0.561     0.519   0.373   0.400
# 490            Troy    0.930     0.134   1.000   0.767
# 491     Los Angeles    0.610     0.063   0.704   0.800
#
# [492 rows x 10 columns]

# %% [markdown]
# ### 6

# %%
normd.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_4ceb8_row0_col0, #T_4ceb8_row1_col1, #T_4ceb8_row2_col2, #T_4ceb8_row3_col3, #T_4ceb8_row4_col4 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_4ceb8_row0_col1, #T_4ceb8_row2_col3, #T_4ceb8_row2_col4, #T_4ceb8_row3_col2, #T_4ceb8_row4_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_4ceb8_row0_col2 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_4ceb8_row0_col3 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_4ceb8_row0_col4 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_4ceb8_row1_col0 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_4ceb8_row1_col2 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_4ceb8_row1_col3 {
#   background-color: #d85646;
#   color: #f1f1f1;
# }
# #T_4ceb8_row1_col4 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_4ceb8_row2_col0 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_4ceb8_row2_col1 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_4ceb8_row3_col0 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_4ceb8_row3_col1 {
#   background-color: #e67259;
#   color: #f1f1f1;
# }
# #T_4ceb8_row3_col4 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_4ceb8_row4_col1 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_4ceb8_row4_col2 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_4ceb8_row4_col3 {
#   background-color: #f7b497;
#   color: #000000;
# }
# </style>
# <table id="T_4ceb8_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Employees</th>
#       <th class="col_heading level0 col1" >Revenue</th>
#       <th class="col_heading level0 col2" >Expenses</th>
#       <th class="col_heading level0 col3" >Profit</th>
#       <th class="col_heading level0 col4" >Growth</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4ceb8_level0_row0" class="row_heading level0 row0" >Employees</th>
#       <td id="T_4ceb8_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_4ceb8_row0_col1" class="data row0 col1" >-0.050062</td>
#       <td id="T_4ceb8_row0_col2" class="data row0 col2" >0.026244</td>
#       <td id="T_4ceb8_row0_col3" class="data row0 col3" >-0.055990</td>
#       <td id="T_4ceb8_row0_col4" class="data row0 col4" >-0.072105</td>
#     </tr>
#     <tr>
#       <th id="T_4ceb8_level0_row1" class="row_heading level0 row1" >Revenue</th>
#       <td id="T_4ceb8_row1_col0" class="data row1 col0" >-0.050062</td>
#       <td id="T_4ceb8_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_4ceb8_row1_col2" class="data row1 col2" >-0.007543</td>
#       <td id="T_4ceb8_row1_col3" class="data row1 col3" >0.830909</td>
#       <td id="T_4ceb8_row1_col4" class="data row1 col4" >0.436724</td>
#     </tr>
#     <tr>
#       <th id="T_4ceb8_level0_row2" class="row_heading level0 row2" >Expenses</th>
#       <td id="T_4ceb8_row2_col0" class="data row2 col0" >0.026244</td>
#       <td id="T_4ceb8_row2_col1" class="data row2 col1" >-0.007543</td>
#       <td id="T_4ceb8_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_4ceb8_row2_col3" class="data row2 col3" >-0.562660</td>
#       <td id="T_4ceb8_row2_col4" class="data row2 col4" >-0.238084</td>
#     </tr>
#     <tr>
#       <th id="T_4ceb8_level0_row3" class="row_heading level0 row3" >Profit</th>
#       <td id="T_4ceb8_row3_col0" class="data row3 col0" >-0.055990</td>
#       <td id="T_4ceb8_row3_col1" class="data row3 col1" >0.830909</td>
#       <td id="T_4ceb8_row3_col2" class="data row3 col2" >-0.562660</td>
#       <td id="T_4ceb8_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_4ceb8_row3_col4" class="data row3 col4" >0.493520</td>
#     </tr>
#     <tr>
#       <th id="T_4ceb8_level0_row4" class="row_heading level0 row4" >Growth</th>
#       <td id="T_4ceb8_row4_col0" class="data row4 col0" >-0.072105</td>
#       <td id="T_4ceb8_row4_col1" class="data row4 col1" >0.436724</td>
#       <td id="T_4ceb8_row4_col2" class="data row4 col2" >-0.238084</td>
#       <td id="T_4ceb8_row4_col3" class="data row4 col3" >0.493520</td>
#       <td id="T_4ceb8_row4_col4" class="data row4 col4" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
tempdf = pd.DataFrame(normd.groupby('Industry').City.nunique()).reset_index().sort_values(by="City", ascending = False)
tempdf.plot.bar(x = 'Industry', y = 'City', figsize = (17, 7), rot = 0, title = "Distinct city count by Industry")
# Out:
# <AxesSubplot:title={'center':'Total count by Industry'}, xlabel='Industry'>

# %%
tempdf
# Out:
#               Industry  City
# 4          IT Services   106
# 3               Health    71
# 6             Software    49
# 1   Financial Services    45
# 0         Construction    44
# 5               Retail    44
# 2  Government Services    37

# %%
values = normd.groupby(['Inception', 'Industry']).Industry.count().values
cols = normd.groupby(['Inception', 'Industry']).Industry.count().index.values
tempdf = pd.DataFrame([(cols[i][0], cols[i][1], values[i]) for i in range(len(values))], columns = ['Inception', 'Industry', 'Count'])
sns.lineplot(data=tempdf,x='Inception', y = 'Count', hue='Industry', linewidth = 3)
# Out:
# <AxesSubplot:xlabel='Inception', ylabel='Count'>

# %%
normd
# Out:
#                  Name      Industry Inception  Employees State  \
# 0            Over-Hex      Software    2006.0      0.003    TN
# 1           Unimattax   IT Services    2009.0      0.005    PA
# 2            Greenfax        Retail    2012.0      0.004    SC
# 3           Blacklane   IT Services    2011.0      0.009    CA
# 4            Yearflex      Software    2013.0      0.006    WI
# ..                ...           ...       ...        ...   ...
# 487  Buretteadmirable   IT Services    2009.0      0.013    ME
# 488  Inventtremendous  Construction    2009.0      0.003    MN
# 489    Overviewparrot        Retail    2011.0      1.000    TX
# 490        Belaguerra   IT Services    2010.0      0.020    MI
# 491       Allpossible   IT Services    2011.0      0.003    CA
#
#                City  Revenue  Expenses  Profit  Growth
# 0          Franklin    0.476     0.108   0.534   0.633
# 1    Newtown Square    0.731     0.075   0.826   0.667
# 2        Greenville    0.480     0.099   0.544   0.533
# 3            Orange    0.811     0.466   0.670   0.633
# 4           Madison    0.410     0.440   0.262   0.633
# ..              ...      ...       ...     ...     ...
# 487        Portland    0.814     0.282   0.786   0.833
# 488        Woodbury    0.444     0.479   0.274   0.367
# 489      Fort Worth    0.561     0.519   0.373   0.400
# 490            Troy    0.930     0.134   1.000   0.767
# 491     Los Angeles    0.610     0.063   0.704   0.800
#
# [492 rows x 10 columns]
