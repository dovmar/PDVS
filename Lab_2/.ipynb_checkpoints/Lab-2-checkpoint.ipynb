# %% [markdown]
# Data: https://www.kaggle.com/cnic92/spotify-past-decades-songs-50s10s <br>

# %%
import matplotlib.pyplot as plt
import pandas as pd

def read_clean_data(filename):
    d = pd.read_csv(filename)[['bpm', 'nrgy', 'dnce', 'dB','live', 'val', 'dur','acous', 'spch','pop']]
    d = d.rename({'bpm':'tempo','nrgy':'energy','dnce':'danceability','dB':'loudness','live':'liveness',
                  'val':'valence','dur':'duration','acous':'acousticness','spch':'speechiness','pop':'popularity'},
                 axis = 1)
    d['decade'] = filename[2:4] + 's'
    return d

# %% [markdown]
# ### 1

# %%
filenames = ['1950.csv','1980.csv','2010.csv']

df = pd.concat([read_clean_data(i) for i in filenames])

# %%
df.groupby('decade').mean()
# Out:
#              tempo     energy  danceability   loudness   liveness    valence  \
# decade
# 10s     118.720000  67.980000     65.370000  -5.490000  17.930000  46.350000
# 50s     111.150685  34.890411     51.027397 -11.616438  18.150685  57.589041
# 80s     122.609524  64.895238     62.276190  -9.095238  16.419048  63.123810
#
#           duration  acousticness  speechiness  popularity
# decade
# 10s     209.170000     14.710000     8.440000   75.970000
# 50s     149.534247     73.013699     4.191781   40.863014
# 80s     258.942857     24.571429     4.419048   67.704762

# %%
df.groupby('decade')['tempo'].count().plot.bar(rot = 0, figsize = (10, 5))
# Out:
# <AxesSubplot:xlabel='decade'>

# %% [markdown]
# ## PCA

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

def plot_pca(x_pca, exvar):    
    pc1 = str(round(100*exvar[0], 2))
    pc2 = str(round(100*exvar[1], 2))
    
    fig = plt.figure(figsize=(20, 9))
    ax = fig.add_subplot(1,1,1) 
    ax.set_xlabel("Principal Component 1 " + pc1 + "%") 
    ax.set_ylabel("Principal Component 2 " + pc2 + "%") 
    ax.set_title("2 component PCA") 
    targets = ['50s',  '80s', '10s']
    colors = ['tab:blue', 'tab:orange', 'tab:green',]
    for target, color in zip(targets,colors):
        indicesToKeep = x_pca['key'] == target
        ax.scatter(x_pca.loc[indicesToKeep, 'PC1']
                   , x_pca.loc[indicesToKeep, 'PC2']
                   , c = color
                   , s = 200
                   , alpha = 0.5)
    ax.legend(targets)
    ax.grid()
    
def do_pca(df, standartize = False):
    x = df.loc[:, df.columns[:-1]].values
    y = df.loc[:,['decade']].values
    if standartize:
        x = StandardScaler().fit_transform(x)
    x = pd.DataFrame(x)

    pca = PCA()
    x_pca = pca.fit_transform(x)
    x_pca = pd.DataFrame(x_pca)

    exvar = pca.explained_variance_ratio_
    pd.DataFrame(
        {"explained":exvar, "PCA":["PCA"+str(i) for i in range(1, len(exvar)+1)]}
    ).plot.bar(x = 'PCA', y = 'explained', figsize = (10, 6))
    
    x_pca['key']= y
    names = ["PC" + str(i) for i in range(len(x_pca.columns)-1)]
    names.append("key")
    x_pca.columns = names
    
    plot_pca(x_pca, exvar)

# %% [markdown]
# #### not standartized

# %%
do_pca(df, False)

# %% [markdown]
# #### standartized

# %%
do_pca(df, True)

# %% [markdown]
# ## MDS

# %%
import plotly.express as px 
from sklearn.manifold import MDS 

def plot_mds(df):
    fig = plt.figure(figsize=(20, 9))
    ax = fig.add_subplot(1,1,1) 
    ax.set_xlabel("MDS1") 
    ax.set_ylabel("MDS2") 
    ax.set_title("2 dimensional MDS") 
    targets = ['50s',  '80s', '10s']
    colors = ['b', 'g', 'r',]
    for target, color in zip(targets,colors):
        indicesToKeep = df['key'] == target
        ax.scatter(df.loc[indicesToKeep, 'PC1']
                    , df.loc[indicesToKeep, 'PC2']
                    , c = color
                    , s = 200
                    , alpha = 0.4)
    ax.legend(targets)
    ax.grid()
    
def do_mds(df, standartize = False,metric=True):
    model2d=MDS(n_components=2, 
          metric=metric, 
          n_init=4, 
          max_iter=1000, 
          verbose=0, 
          eps=0.001, 
          n_jobs=None,  
          dissimilarity='euclidean')
    
    x = df.loc[:, df.columns[:-1]].values
    y = df.loc[:,['decade']].values
    if standartize:
        x = StandardScaler().fit_transform(x)
    x = pd.DataFrame(x)
    
    X_trans = model2d.fit_transform(x)

    print('Iterations: ', model2d.n_iter_)
    print('Stress: ', model2d.stress_)
    
    X_trans = X_trans.reshape(2, -1)
    y = y.flatten()
    toplot = pd.DataFrame({"PC1":X_trans[0],"PC2":X_trans[1],"key":y})
    
    plot_mds(toplot)

# %% [markdown]
# #### not standartized

# %%
do_mds(df, False)
# Out:
# Iterations:  197
# Stress:  14911512.523034517

# %% [markdown]
# #### standartized

# %%
do_mds(df, True)
# Out:
# Iterations:  470
# Stress:  44546.10612348824

# %%
do_mds(df, True, False) # su nemetrikiniu variantu
# Out:
# Iterations:  3
# Stress:  1739.2851204962747

# %%
# Apskaiciuoti atstumus ranka su kazkokiu kitu atstumu is sklearn.metrics.pairwise_distances
# per MDS nustatyti distance=‘precomputed’
# ir per .fit paduoti ta atstumu matrica

# nors gal sitas dalis pasilikti tam musu MDS pristatymui

# %%
from sklearn.manifold import TSNE


def plot_mds(df):
    fig = plt.figure(figsize=(20, 9))
    ax = fig.add_subplot(1,1,1) 
    ax.set_xlabel("t-SNE1") 
    ax.set_ylabel("t-SNE2") 
    ax.set_title("2 dimensional t-SNE") 
    targets = ['50s',  '80s', '10s']
    colors = ['b', 'g', 'r',]
    for target, color in zip(targets,colors):
        indicesToKeep = df['key'] == target
        ax.scatter(df.loc[indicesToKeep, 'PC1']
                    , df.loc[indicesToKeep, 'PC2']
                    , c = color
                    , s = 200
                    , alpha = 0.4)
    ax.legend(targets)
    ax.grid()
    
    
def do_tsne(df, standartize = False,perplexity=30):
    model2d=TSNE(n_components=2, 
          perplexity = perplexity,
          n_iter=1000, 
          verbose=0)
    
    x = df.loc[:, df.columns[:-1]].values
    y = df.loc[:,['decade']].values
    if standartize:
        x = StandardScaler().fit_transform(x)
    x = pd.DataFrame(x)
    
    X_trans = model2d.fit_transform(x)

    print('Iterations: ', model2d.n_iter_)
    print('kl divergence: ', model2d.kl_divergence_)
    
    X_trans = X_trans.reshape(2, -1)
    y = y.flatten()
    toplot = pd.DataFrame({"PC1":X_trans[0],"PC2":X_trans[1],"key":y})
    
    plot_mds(toplot)

# %%
do_tsne(df, True,20)
# Out:
# Iterations:  999
# kl divergence:  0.7542052865028381

# %%
do_tsne(df, True,50)
# Out:
# Iterations:  999
# kl divergence:  0.5168428421020508

# %%
do_tsne(df, True,100)
# Out:
# Iterations:  999
# kl divergence:  0.27980276942253113
